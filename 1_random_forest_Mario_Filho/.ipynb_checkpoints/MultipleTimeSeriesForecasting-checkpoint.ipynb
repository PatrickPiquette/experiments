# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_log_error
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor

# %%
data = pd.read_csv('Sales_Transactions_Dataset_Weekly.csv')

# %%
data.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8      ...        \
# 0           P1  11  12  10   8  13  12  14  21   6      ...
# 1           P2   7   6   3   2   7   1   6   3   3      ...
# 2           P3   7  11   8   9  10   8   7  13  12      ...
# 3           P4  12   8  13   5   9   6   9  13  13      ...
# 4           P5   8   5  13  11   6   7   9  14   9      ...
#
#    Normalized 42  Normalized 43  Normalized 44  Normalized 45  Normalized 46  \
# 0           0.06           0.22           0.28           0.39           0.50
# 1           0.20           0.40           0.50           0.10           0.10
# 2           0.27           1.00           0.18           0.18           0.36
# 3           0.41           0.47           0.06           0.12           0.24
# 4           0.27           0.53           0.27           0.60           0.20
#
#    Normalized 47  Normalized 48  Normalized 49  Normalized 50  Normalized 51
# 0           0.00           0.22           0.17           0.11           0.39
# 1           0.40           0.50           0.10           0.60           0.00
# 2           0.45           1.00           0.45           0.45           0.36
# 3           0.35           0.71           0.35           0.29           0.35
# 4           0.20           0.13           0.53           0.33           0.40
#
# [5 rows x 107 columns]

# %%
data = data.filter(regex=r'Product|W')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 53 columns):
# Product_Code    811 non-null object
# W0              811 non-null int64
# W1              811 non-null int64
# W2              811 non-null int64
# W3              811 non-null int64
# W4              811 non-null int64
# W5              811 non-null int64
# W6              811 non-null int64
# W7              811 non-null int64
# W8              811 non-null int64
# W9              811 non-null int64
# W10             811 non-null int64
# W11             811 non-null int64
# W12             811 non-null int64
# W13             811 non-null int64
# W14             811 non-null int64
# W15             811 non-null int64
# W16             811 non-null int64
# W17             811 non-null int64
# W18             811 non-null int64
# W19             811 non-null int64
# W20             811 non-null int64
# W21             811 non-null int64
# W22             811 non-null int64
# W23             811 non-null int64
# W24             811 non-null int64
# W25             811 non-null int64
# W26             811 non-null int64
# W27             811 non-null int64
# W28             811 non-null int64
# W29             811 non-null int64
# W30             811 non-null int64
# W31             811 non-null int64
# W32             811 non-null int64
# W33             811 non-null int64
# W34             811 non-null int64
# W35             811 non-null int64
# W36             811 non-null int64
# W37             811 non-null int64
# W38             811 non-null int64
# W39             811 non-null int64
# W40             811 non-null int64
# W41             811 non-null int64
# W42             811 non-null int64
# W43             811 non-null int64
# W44             811 non-null int64
# W45             811 non-null int64
# W46             811 non-null int64
# W47             811 non-null int64
# W48             811 non-null int64
# W49             811 non-null int64
# W50             811 non-null int64
# W51             811 non-null int64
# dtypes: int64(52), object(1)
# memory usage: 335.9+ KB

# %% [markdown]
# so there is 811 timeseries of 52 elements (weeks)

# %%
data.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W42  W43  W44  W45  \
# 0           P1  11  12  10   8  13  12  14  21   6 ...     4    7    8   10
# 1           P2   7   6   3   2   7   1   6   3   3 ...     2    4    5    1
# 2           P3   7  11   8   9  10   8   7  13  12 ...     6   14    5    5
# 3           P4  12   8  13   5   9   6   9  13  13 ...     9   10    3    4
# 4           P5   8   5  13  11   6   7   9  14   9 ...     7   11    7   12
#
#    W46  W47  W48  W49  W50  W51
# 0   12    3    7    6    5   10
# 1    1    4    5    1    6    0
# 2    7    8   14    8    8    7
# 3    6    8   14    8    7    8
# 4    6    6    5   11    8    9
#
# [5 rows x 53 columns]

# %%
melt = data.melt(id_vars='Product_Code', var_name='Week', value_name='Sales')

# %%
melt.head()
# Out:
#   Product_Code Week  Sales
# 0           P1   W0     11
# 1           P2   W0      7
# 2           P3   W0      7
# 3           P4   W0     12
# 4           P5   W0      8

# %%
melt['Product_Code'] = melt['Product_Code'].str.extract('(\d+)', expand=False).astype(int)

# %%
melt.head()
# Out:
#    Product_Code Week  Sales
# 0             1   W0     11
# 1             2   W0      7
# 2             3   W0      7
# 3             4   W0     12
# 4             5   W0      8

# %%
melt['Week'] = melt['Week'].str.extract('(\d+)', expand=False).astype(int)

# %%
melt.head()
# Out:
#    Product_Code  Week  Sales
# 0             1     0     11
# 1             2     0      7
# 2             3     0      7
# 3             4     0     12
# 4             5     0      8

# %%
melt = melt.sort_values(by=['Week', 'Product_Code'])

# %%
melt.head()
# Out:
#    Product_Code  Week  Sales
# 0             1     0     11
# 1             2     0      7
# 2             3     0      7
# 3             4     0     12
# 4             5     0      8

# %% [markdown]
# # Basic Feature Engineering
# We need to have variables to send to our model and get the predictions. For now, besides the product code and the week, I will create two features that usually help a lot with time series: lags and differences.
#
# **Last Week Sales**: this is simply the amount of sales that a product had in the previous week
#
# **Last Week Diff**: the difference between the amount of sales in the previous week and the week before it ((t-1) - (t-2))

# %%
melt2 = melt.copy()
melt2['Last_Week_Sales'] = melt2.groupby(['Product_Code']).shift()['Sales']
melt2['Last_Week_Diff'] = melt2.groupby(['Product_Code']).diff()['Last_Week_Sales']
melt2 = melt2.dropna()
melt2.head()
# Out:
#       Product_Code  Week  Sales  Last_Week_Sales  Last_Week_Diff
# 1622             1     2     10             12.0             1.0
# 1623             2     2      3              6.0            -1.0
# 1624             3     2      8             11.0             4.0
# 1625             4     2     13              8.0            -4.0
# 1626             5     2     13              5.0            -3.0

# %% [markdown]
# # Evaluating the Result
# To know if our model is good we need to have an evaluation metric. A metric I really like for sales forecasting is the Root Mean Squared Log Error.
#
# This is our well-known RMSE applied to the log of the target and the prediction output.
#
# It works as an approximation to the percentage error between our predictions and the target, which is a nice way to understand the errors our model is making.

# %%
def rmsle(ytrue, ypred):
    return np.sqrt(mean_squared_log_error(ytrue, ypred))

# %% [markdown]
# # Setting a Baseline and a Validation Split
# Let's say that in real life your model will run every Sunday night, so that early on Monday the managers can make decisions based on the predictions for the next week.
#
# To see if our model will work in this scenario, weeks it has not seen before, I will use a sliding window validation. This means that we are going to simulate training the model in all the weeks up to the one we want to predict, and evaluate our score in the new week.
#
# And, to avoid having a very good model in a small amount of weeks simply due to luck, I will use every week from 40 to 52, repeating the process for one at a time, and compute the score.
#
# As this is only a demonstration of the method, to keep it simple I am not separating a test set. In your projects, always keep some periods out of your validation to evaluate your model when you finish developing it. **This is very important**, and helps you be more secure about your model performing well when deployed.
#
# To make sure the model is worth using I like to set a baseline score that it has to beat. In this case, **a reasonably strong baseline is using the last week amount of sales as a prediction for the sales this week**.

# %%
mean_error = []
for week in range(40,52):
    # train dataset and next value to be as close as possible
    train = melt2[melt2['Week'] < week] # not used here
    val = melt2[melt2['Week'] == week]

    error = rmsle(val['Sales'].values, val['Last_Week_Sales'].values)
    print('Week %d - Error %.5f' % (week, error))
    mean_error.append(error)
    
print('Mean Error = %.5f' % np.mean(mean_error))
# Out:
# Week 40 - Error 0.51952
# Week 41 - Error 0.51691
# Week 42 - Error 0.51026
# Week 43 - Error 0.50792
# Week 44 - Error 0.53409
# Week 45 - Error 0.52347
# Week 46 - Error 0.50018
# Week 47 - Error 0.49138
# Week 48 - Error 0.50585
# Week 49 - Error 0.50547
# Week 50 - Error 0.52220
# Week 51 - Error 0.55242
# Mean Error = 0.51581

# %% [markdown]
# Now we know that our model has to have a better error than about 0.51. This would be approximately 50% error in each prediction, which seems huge! But is it really?
#
# If we look at the distribution of sales in the dataset, we see that a lot of items sell very little amounts. So we should expect the error to look "high".

# %%
sns.distplot(melt2['Sales'], bins=10)

# %% [markdown]
# # Creating the Model
# Now that we have a baseline, let's try to beat it!
#
# As a first model, let's train a Random Forest. Besides being a strong model with structured data (like the one we have), we usually can already get a very good result by just setting a high number of trees.
#
# I usually tell data scientists that a Random Forest is a very good model to use in a lazy day. You only set the number of trees to the maximum your computer can run and get a good model (hopefully).
#
# I will keep the Week as a feature although our model will have never seen the new week value. It may be that after week 35, for example, we have more sales for a product. This type of effect can be captured by the model.
#
# As decision trees can handle categorical features well even in ordinal encoding, I left them in this format.
#
# Anyway, be careful with these types of features.

# %% [markdown]
# **The following model is train on all 811 timeseries with no distinction for the product. Once trained each product is predicted and we mean the results**

# %%
def train_predict(melt, log=False, mdl=None):
    mean_error = []
    for week in range(40,52):
        train = melt[melt['Week'] < week]
        val = melt[melt['Week'] == week]

        # X is all but Sales
        # y is Sales
        xtr = train.drop(['Sales'], axis=1)
        ytr = train['Sales'].values
        xts = val.drop(['Sales'], axis=1)
        yts = val['Sales'].values

        if log == False:
            mdl.fit(xtr, ytr)
            p = mdl.predict(xts)
        else:
            # use later in this notebook
            mdl.fit(xtr, np.log1p(ytr))
            p = np.expm1(mdl.predict(xts))


        error = rmsle(yts, p)
        print('Week %d - Error %.5f' % (week, error))
        mean_error.append(error)

    print('Mean Error = %.5f' % np.mean(mean_error))
    return p # return the last prediction (week 52)
    
train_predict(melt2, mdl=RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=0))
# Out:
# Week 40 - Error 0.46120
# Week 41 - Error 0.45778
# Week 42 - Error 0.46563
# Week 43 - Error 0.46627
# Week 44 - Error 0.47322
# Week 45 - Error 0.43089
# Week 46 - Error 0.47313
# Week 47 - Error 0.45241
# Week 48 - Error 0.46594
# Week 49 - Error 0.44915
# Week 50 - Error 0.47542
# Week 51 - Error 0.48685
# Mean Error = 0.46316
# array([1.200e+01, 2.500e+00, 9.410e+00, 1.151e+01, 1.026e+01, 7.900e+00,
#        2.670e+00, 2.430e+00, 3.930e+00, 4.930e+00, 1.150e+00, 9.000e-02,
#        9.300e-01, 5.100e+00, 8.500e-01, 1.800e-01, 2.900e-01, 4.000e-01,
#        2.800e-01, 5.600e-01, 2.230e+00, 2.200e-01, 1.958e+01, 5.140e+00,
#        2.110e+01, 7.700e+00, 3.430e+00, 5.190e+00, 4.790e+00, 3.940e+00,
#        9.340e+00, 2.780e+00, 1.025e+01, 3.050e+00, 7.440e+00, 4.910e+00,
#        4.800e-01, 5.250e+00, 4.880e+00, 2.380e+00, 7.550e+00, 6.720e+00,
#        5.330e+00, 4.500e+00, 4.550e+00, 4.270e+00, 2.870e+00, 8.530e+00,
#        4.230e+00, 5.190e+00, 3.350e+00, 9.600e-01, 3.980e+00, 8.400e-01,
#        2.970e+00, 1.314e+01, 1.440e+00, 4.600e+00, 3.730e+00, 1.440e+00,
#        7.000e-01])

# %% [markdown]
# Nice!
#
# Applying the Random Forest to our initial variables we got a good reduction of the error (about 10%). This is a very good way to start.
#
# Now, let's try to add some features from more weeks in the past. First, let's add the lag and the difference of sales for the week before the previous.

# %%
melt3 = melt.copy()
melt3['Last_Week_Sales'] = melt3.groupby(['Product_Code'])['Sales'].shift()
melt3['Last_Week_Diff'] = melt3.groupby(['Product_Code'])['Last_Week_Sales'].diff()
melt3['Last-1_Week_Sales'] = melt3.groupby(['Product_Code'])['Sales'].shift(2)
melt3['Last-1_Week_Diff'] = melt3.groupby(['Product_Code'])['Last-1_Week_Sales'].diff()
melt3 = melt3.dropna()
melt3.head()
# Out:
#       Product_Code  Week  Sales  Last_Week_Sales  Last_Week_Diff  \
# 2433             1     3      8             10.0            -2.0
# 2434             2     3      2              3.0            -3.0
# 2435             3     3      9              8.0            -3.0
# 2436             4     3      5             13.0             5.0
# 2437             5     3     11             13.0             8.0
#
#       Last-1_Week_Sales  Last-1_Week_Diff
# 2433               12.0               1.0
# 2434                6.0              -1.0
# 2435               11.0               4.0
# 2436                8.0              -4.0
# 2437                5.0              -3.0

# %%
train_predict(melt3, mdl=RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=0))
# Out:
# Week 40 - Error 0.44670
# Week 41 - Error 0.46178
# Week 42 - Error 0.44017
# Week 43 - Error 0.44477
# Week 44 - Error 0.46291
# Week 45 - Error 0.42519
# Week 46 - Error 0.46017
# Week 47 - Error 0.44349
# Week 48 - Error 0.44577
# Week 49 - Error 0.43562
# Week 50 - Error 0.47510
# Week 51 - Error 0.46828
# Mean Error = 0.45083

# %% [markdown]
# Great! Another reduction!
#
# Can you guess my next idea?
#
# Let's try a model with one more lag and difference, of course!

# %%
melt4 = melt.copy()
melt4['Last_Week_Sales'] = melt4.groupby(['Product_Code'])['Sales'].shift()
melt4['Last_Week_Diff'] = melt4.groupby(['Product_Code'])['Last_Week_Sales'].diff()
melt4['Last-1_Week_Sales'] = melt4.groupby(['Product_Code'])['Sales'].shift(2)
melt4['Last-1_Week_Diff'] = melt4.groupby(['Product_Code'])['Last-1_Week_Sales'].diff()
melt4['Last-2_Week_Sales'] = melt4.groupby(['Product_Code'])['Sales'].shift(3)
melt4['Last-2_Week_Diff'] = melt4.groupby(['Product_Code'])['Last-2_Week_Sales'].diff()
melt4 = melt4.dropna()
melt4.head()
# Out:
#       Product_Code  Week  Sales  Last_Week_Sales  Last_Week_Diff  \
# 3244             1     4     13              8.0            -2.0
# 3245             2     4      7              2.0            -1.0
# 3246             3     4     10              9.0             1.0
# 3247             4     4      9              5.0            -8.0
# 3248             5     4      6             11.0            -2.0
#
#       Last-1_Week_Sales  Last-1_Week_Diff  Last-2_Week_Sales  Last-2_Week_Diff
# 3244               10.0              -2.0               12.0               1.0
# 3245                3.0              -3.0                6.0              -1.0
# 3246                8.0              -3.0               11.0               4.0
# 3247               13.0               5.0                8.0              -4.0
# 3248               13.0               8.0                5.0              -3.0

# %%
train_predict(melt4, mdl=RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=0))
# Out:
# Week 40 - Error 0.43286
# Week 41 - Error 0.43986
# Week 42 - Error 0.43061
# Week 43 - Error 0.42074
# Week 44 - Error 0.45081
# Week 45 - Error 0.41358
# Week 46 - Error 0.44129
# Week 47 - Error 0.43286
# Week 48 - Error 0.43838
# Week 49 - Error 0.43048
# Week 50 - Error 0.46058
# Week 51 - Error 0.45568
# Mean Error = 0.43731

# %% [markdown]
# # Changing the Loss Function (and Target Distribution)¶
# We are evaluating our results using the log of our predictions and target, but we are training using them in their original form, so we are optimizing the model using the MSE instead of the MSLE.
#
# Usually you get an improvement by using the same function to evaluate and optimize your model. In this case we can do this by simply taking the log of our target variable before passing it to the fit model.
#
# Sometimes it's not possible to optimize the evaluation function directly. In this case, look for an approximation. We can say we are already using an approximation here (of the percentage error).
#
# By taking the log of the target we get the added bonus that its distribution will look closer to a normal distribution. This usually helps the model learn better.

# %%
train_predict(melt4, log=True, mdl=RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=0))
# Out:
# Week 40 - Error 0.41826
# Week 41 - Error 0.42729
# Week 42 - Error 0.41029
# Week 43 - Error 0.40741
# Week 44 - Error 0.43658
# Week 45 - Error 0.40124
# Week 46 - Error 0.42583
# Week 47 - Error 0.41662
# Week 48 - Error 0.43488
# Week 49 - Error 0.43670
# Week 50 - Error 0.44912
# Week 51 - Error 0.47201
# Mean Error = 0.42802
# array([4.98959928e+00, 4.04799786e+00, 8.01406866e+00, 8.49160808e+00,
#        7.12488074e+00, 4.64956324e+00, 4.40109710e+00, 7.36339752e+00,
#        9.75905558e+00, 1.81596194e+01, 1.01369379e+01, 2.92876899e+00,
#        1.28331981e+01, 8.16534723e+00, 2.97280719e+01, 2.92002367e+01,
#        2.98734744e+01, 2.51249040e+01, 2.75460426e+01, 8.00078189e+00,
#        8.91846986e+00, 8.77893320e+00, 2.73435347e+00, 3.01433866e+01,
#        3.07986445e+01, 8.79418879e+00, 3.05172165e+01, 2.74934723e+01,
#        1.09904570e+01, 2.82887095e+01, 6.14287805e+00, 6.21618702e+00,
#        1.61112235e+01, 3.09528937e+01, 2.54300558e+01, 2.93982458e+01,
#        6.15858660e+00, 2.22069482e+00, 5.27486429e+00, 1.73415748e+00,
#        4.68879740e+00, 1.90199421e+00, 1.01505190e+00, 3.74675941e+00,
#        4.83958215e+00, 2.17301696e+00, 5.42845192e+00, 4.35048748e+00,
#        4.43308734e+00, 2.19750766e+00, 2.27886167e+00, 3.94207715e+00,
#        2.05185050e+00, 5.66700403e+00, 3.87132745e+00, 3.99338860e+00,
#        2.72908939e+00, 2.01782284e+00, 3.99614728e+00, 9.99522349e-01,
#        2.70220376e+00, 5.70598499e+00, 1.44096407e+00, 4.66945901e+00,
#        2.46875164e-01, 2.26968108e-01, 1.10466919e-02])

# %% [markdown]
# # A Better Model
# Anyone that ever stumbled over a machine learning competition solution may know about the love of competitors for Gradient Boosted Trees. I am guilty of this too!
#
# It's very common to have the best results with this type of model, which is an ensemble of trees like a Random Forest, but the method that it uses to create and combine the trees is different. Worth understanding.
#
# This is a very good scenario for us to try this model and see if we can reduce the error even more!
#
# There are many parameters we can tune for this model, but I will simply put 1000 trees with a small learning rate. If you want to improve the prediction, you can try tuning it and leave a comment about the improvement you got.

# %%
p = train_predict(melt4, log=True, mdl=LGBMRegressor(n_estimators=400, learning_rate=0.01))
# Out:
# Week 40 - Error 0.40915
# Week 41 - Error 0.40005
# Week 42 - Error 0.39584
# Week 43 - Error 0.39500
# Week 44 - Error 0.42232
# Week 45 - Error 0.37963
# Week 46 - Error 0.40532
# Week 47 - Error 0.39120
# Week 48 - Error 0.39814
# Week 49 - Error 0.41191
# Week 50 - Error 0.42273
# Week 51 - Error 0.45663
# Mean Error = 0.40733

# %% [markdown]
# Very good!
#
# This model gave us a sizeable improvement, we are almost below the 0.40 barrier. Let's take a look at our predictions for Week 52.

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.scatter(np.round(p), yts)
lim = 40
z = range(1,lim,1)
axes.plot(z,z)
axes.set_xlim(right=lim)
axes.set_ylim(top=lim)
# Out:
# (-3.661458333333333, 40)

# %%
data = pd.DataFrame(data=yts, columns=['Sale Amount'])
data['Prediction'] = p
data['Error'] = np.square(data['Prediction'] - data['Sale Amount'])
data.drop(index=data[data['Sale Amount']==73].index, inplace=True)
data2=data.groupby('Sale Amount').mean()
data2['Error'] = data2['Error'].apply(np.sqrt)
data2.head()
# Out:
#              Prediction     Error
# Sale Amount
# 0              0.476829  0.845836
# 1              0.928109  1.012495
# 2              1.674741  1.576231
# 3              2.826472  1.698544
# 4              3.568810  1.707505

# %%
data2.plot( y='Error', kind='line', title="The RMS of the Error per sale amount")

# %% [markdown]
# The previous shosw that the error is worst for larget sale amounts
#
# The following looks at the repartition of the data in the dataset for different sale amounts

# %%
melt4_gb = melt4.copy()
melt4_gb['Number'] = np.ones(len(melt4_gb))
melt4_gb = melt4_gb.groupby('Sales').sum()
melt4_gb.sort_values(by='Sales')
melt4_gb.reset_index(inplace=True)
melt4_gb.plot(x='Sales', y='Number', title="Number of entries in the dataset per sale price")

# %% [markdown]
# It looks like there are a huge amount of entries for small amounts. This probably confuse explain the bad results as sale price increase.
